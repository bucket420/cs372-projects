# %%
import math
from pqueue import PQueue
import time

# Returns a dictionary that maps a location to its coordinates { ID: (latitude, longitude) }
def get_locations(file):
    file = open(file)
    loc_dict = {}
    for line in file:
        line = line.strip()
        line = line.split('|')
        # print(line)
        if line[0] == 'location':
            loc_dict[line[1]] = (float(line[2]), float(line[3]))
    file.close()
    return loc_dict            

# Returns a dictionary that maps a location to a collection of locations that's connected to it { ID1: {ID2 : (speed limit, road name)} }
def get_roads(file):
    file = open(file)
    loc_to_roads = {}
    for line in file:
        line = line.strip()
        line = line.split('|')
        if line[0] == 'road':
            if line[1] not in loc_to_roads.keys():
                loc_to_roads[line[1]] = { line[2] : (float(line[3]), line[4]) }
            else:
                loc_to_roads[line[1]][line[2]] = (float(line[3]), line[4])
            if line[2] not in loc_to_roads.keys():
                loc_to_roads[line[2]] = { line[1] : (float(line[3]), line[4]) }
            else:
                loc_to_roads[line[2]][line[1]] = (float(line[3]), line[4])
    file.close()
    return loc_to_roads  

# Calculates the distance between two locations
def distance_on_unit_sphere(lat1, long1, lat2, long2):

    # Convert latitude and longitude to
    # spherical coordinates in radians.
    degrees_to_radians = math.pi/180.0

    # phi = 90 - latitude
    phi1 = (90.0 - lat1)*degrees_to_radians
    phi2 = (90.0 - lat2)*degrees_to_radians

    # theta = longitude
    theta1 = long1*degrees_to_radians
    theta2 = long2*degrees_to_radians

    # Compute spherical distance from spherical coordinates.

    # For two locations in spherical coordinates
    # (1, theta, phi) and (1, theta', phi')
    # cosine( arc length ) =
    # sin phi sin phi' cos(theta-theta') + cos phi cos phi'
    # distance = rho * arc length

    cos = (math.sin(phi1)*math.sin(phi2)*math.cos(theta1 - theta2) +
    math.cos(phi1)*math.cos(phi2))
    arc = math.acos( cos )

    # Remember to multiply arc by the radius of the earth
    # in your favorite set of units to get length.
    return arc * 3960.0

# %%
# Node class
class Node(object):    
    def __init__(self, state, parent, cost):
        self.state = state          # Location ID
        self.parent = parent        # Parent node
        self.cost = cost            # Cost to reach from initial location

# Expands a node
def expand(node : Node, roads, locations):
    children = []
    for child in roads[node.state]:
        current_location = node.state
        next_location = child
        speed = roads[current_location][next_location][0]
        action_cost = distance_on_unit_sphere(locations[current_location][0], locations[current_location][1], locations[next_location][0], locations[next_location][1]) * 3600.0 / speed
        total_cost = node.cost + action_cost
        child_node = Node(child, node, total_cost)
        children.append(child_node)
    return children

# A* algorithm
def A_star(start, goal, locations, roads, debugging):
    start_node = Node(start, None, 0)
    node_count = 0          # Number of nodes visited
    frontier = PQueue()
    frontier.enqueue(start_node, 0)
    reached = { start_node.state : start_node}
    while not frontier.empty():
        node = frontier.dequeue()
        node_count += 1
        if debugging:
            print()
            heuristic = distance_on_unit_sphere(locations[node.state][0], locations[node.state][1], locations[goal][0], locations[goal][1]) * 3600.0 / 65.0
            fn = node.cost + heuristic
            if (node.parent is not None): 
                print("Visiting [State=%s, parent=%s, g=%.15f, h=%.15f, f=%.15f]"%(node.state, node.parent.state, node.cost, heuristic, fn))
            else: 
                print("Visiting [State=%s, parent=null, g=0.0, h=%.15f, f=%.15f]" %(node.state, heuristic, heuristic))
        if (node.state == goal):
            if debugging: print()
            return [node, node_count]
        for child in expand(node, roads, locations):
            heuristic = distance_on_unit_sphere(locations[child.state][0], locations[child.state][1], locations[goal][0], locations[goal][1]) * 3600.0 / 65.0
            fn = child.cost + heuristic
            if child.state not in reached.keys() or child.cost < reached[child.state].cost:
                reached[child.state] = child
                frontier.enqueue(child, fn)
                if debugging: 
                    print("     Adding [State=%s, parent=%s, g=%.15f, h=%.15f, f=%.15f] to frontier." %(child.state, child.parent.state, child.cost, heuristic, fn))
            elif debugging:
                print("     Skipping [State=%s, parent=%s, g=%.15f, h=%.15f, f=%.15f] (already on frontier with lower cost)." %(child.state, child.parent.state, child.cost, heuristic, fn))
    print("fail")
    return

# Returns compass bearing
def get_bearing(lat1, long1, lat2, long2):
  lat1 *= math.pi/180
  lat2 *= math.pi/180
  long1 *= math.pi/180
  long2 *= math.pi/180
  y = math.sin(long2-long1) * math.cos(lat2)
  x = math.cos(lat1) * math.sin(lat2) - math.sin(lat1) * math.cos(lat2) * math.cos(long2-long1)
  angle = math.atan2(y, x)
  bearing = (angle * 180/math.pi + 360) % 360
  return bearing
    
# Gets starting direction
def get_initial_direction(lat1, long1, lat2, long2):
    bearing = get_bearing(lat1, long1, lat2, long2)
    if (337.5 <= bearing <= 359 or 0 <= bearing <= 22.5): return "north"
    elif (22.5 < bearing <= 67.5): return "northeast"
    elif (67.5 < bearing <= 112.5): return "east"
    elif (112.5 < bearing <= 157.5): return "southheast"
    elif (157.5 < bearing <= 202.5): return "south"
    elif (202.5 < bearing <= 247.5): return "southwest"
    elif (247.5 < bearing <= 292.5): return "west"
    else: return "northwest"

# Gets turning direction (lelft or right) 
def get_turning_direction(lat1, long1, lat2, long2, lat3, long3):
    bearing1 = get_bearing(lat1, long1, lat2, long2)    # direction on current road 
    bearing2 = get_bearing(lat2, long2, lat3, long3)    # direction on next road
    if 0 <= bearing1 - bearing2 < 180 or bearing2 - bearing1 >= 180:
        return "left"
    else: 
        return "right"
    
def main():
    # Reading the file
    file = "memphis-medium.txt"
    locations = get_locations(file)
    roads = get_roads(file)
    
    # Getting inputs
    start = input("Enter starting location ID: ")
    goal = input("Enter ending location ID: ")
    debugging = input("Do you want debugging information (y/n)? ") == "y"
    
    # Running A* algorithm 
    node, node_count = A_star(start, goal, locations, roads, debugging)
    
    # Printing results
    print("Total travel time in seconds: %.15f" %(node.cost))
    print("Number of nodes visited: %d\n" %(node_count))
    
    # Reversing the string of nodes
    path = [] 
    while (node.state != start):
        path.insert(0, node)
        node = node.parent
        
    # Printing the route found
    print("Route found is:")
    print("%s (%s)" %(start, "Starting Location"))
    for location in path:
        print("%s (%s)" %(location.state, roads[location.parent.state][location.state][1]))
    print()

    # GPS instructions begin
    print("GPS directions:")
    
    # The very first instruction
    current_location = start
    next_location = path[0].state
    print("Head %s on %s" %(get_initial_direction(locations[current_location][0], locations[current_location][1], locations[next_location][0], locations[next_location][1]), roads[current_location][next_location][1]))

    # Length of a road (not a road segment) and the time it takes to pass it
    road_length = 0
    drive_time = 0
    
    # Printing GPS instructions
    for i in range(len(path)-1):
        last_location = path[i].parent.state
        current_location = path[i].state
        next_location = path[i+1].state
        current_road_name = roads[last_location][current_location][1]
        next_road_name = roads[current_location][next_location][1]
        distance = distance_on_unit_sphere(locations[last_location][0], locations[last_location][1], locations[current_location][0], locations[current_location][1]) # distance traveled on last segment (from last_location to current_location)
        road_length += distance
        drive_time += distance * 3600.0 / roads[last_location][current_location][0]
        if current_road_name == next_road_name:
            continue
        else:
            print("     Drive for %.2f miles (%.2f seconds)" % (road_length, drive_time))
            road_length = 0
            drive_time = 0
            print("Turn %s onto %s" %(get_turning_direction(locations[last_location][0], locations[last_location][1], locations[current_location][0], locations[current_location][1], locations[next_location][0], locations[next_location][1]), roads[current_location][next_location][1]))
    
    # Adding the last segment and print the last instruction
    distance = distance_on_unit_sphere(locations[current_location][0], locations[current_location][1], locations[goal][0], locations[goal][1])
    road_length += distance
    drive_time += distance * 3600.0 / roads[last_location][current_location][0]
    print("     Drive for %.2f miles (%.2f seconds)" % (road_length, drive_time))
    
    # Arrived!!!
    print("You have arrived!")

main()
# Out:
# Total travel time in seconds: 1087.560500867991777
# Number of nodes visited: 18498
#
# Route found is:
# 480814962 (Starting Location)
# 1780794018 (Elvis Presley Boulevard)
# 480816563 (Elvis Presley Boulevard)
# 2421432899 (Elvis Presley Boulevard)
# 2421432902 (Elvis Presley Boulevard)
# 480827094 (Elvis Presley Boulevard)
# 2421432905 (Elvis Presley Boulevard)
# 203812033 (Elvis Presley Boulevard)
# 203812031 (Elvis Presley Boulevard)
# 203812027 (Elvis Presley Boulevard)
# 2421432907 (Elvis Presley Boulevard)
# 203769022 (Elvis Presley Boulevard)
# 1780793911 (Elvis Presley Boulevard)
# 1780793899 (Elvis Presley Boulevard)
# 1780794084 (Elvis Presley Boulevard)
# 2421432909 (Elvis Presley Boulevard)
# 203812011 (Elvis Presley Boulevard)
# 2421432911 (Elvis Presley Boulevard)
# 203690625 (Elvis Presley Boulevard)
# 2421432913 (Elvis Presley Boulevard)
# 2421432916 (Elvis Presley Boulevard)
# 1780794047 (Elvis Presley Boulevard)
# 203812009 (Elvis Presley Boulevard)
# 2421432919 (Elvis Presley Boulevard)
# 203644548 (Elvis Presley Boulevard)
# 1846528059 (Elvis Presley Boulevard)
# 2421432922 (Elvis Presley Boulevard)
# 2421432925 (Elvis Presley Boulevard)
# 203724380 (Elvis Presley Boulevard)
# 2421432932 (Elvis Presley Boulevard)
# 2421432937 (Elvis Presley Boulevard)
# 2421432939 (Elvis Presley Boulevard)
# 2421432945 (Elvis Presley Boulevard)
# 2421432954 (Elvis Presley Boulevard)
# 203812005 (Elvis Presley Boulevard)
# 2421433091 (Elvis Presley Boulevard)
# 2421433131 (Elvis Presley Boulevard)
# 2421433192 (Elvis Presley Boulevard)
# 2421433203 (Elvis Presley Boulevard)
# 203812001 (Elvis Presley Boulevard)
# 2421433243 (Elvis Presley Boulevard)
# 2421433261 (Elvis Presley Boulevard)
# 2421433295 (Elvis Presley Boulevard)
# 2421433303 (Elvis Presley Boulevard)
# 2421433309 (Elvis Presley Boulevard)
# 2421433315 (Elvis Presley Boulevard)
# 203622070 (Elvis Presley Boulevard)
# 2421433373 (NoName)
# 2421433382 (NoName)
# 2421433385 (NoName)
# 203622072 (NoName)
# 1846528098 (NoName)
# 2421433394 (NoName)
# 203622075 (NoName)
# 2421433396 (NoName)
# 2421433399 (NoName)
# 1846528099 (NoName)
# 2421433391 (NoName)
# 203622077 (NoName)
# 2421433388 (NoName)
# 203622080 (NoName)
# 203622082 (NoName)
# 2421433370 (NoName)
# 2421433367 (NoName)
# 203622084 (NoName)
# 2421433364 (NoName)
# 203622085 (NoName)
# 2421433355 (NoName)
# 203622087 (NoName)
# 2421433350 (NoName)
# 203622089 (NoName)
# 2421433341 (NoName)
# 2421433338 (NoName)
# 2421433335 (NoName)
# 203622091 (NoName)
# 2421433332 (NoName)
# 203622092 (NoName)
# 2421433344 (NoName)
# 2421433347 (NoName)
# 281878237 (NoName)
# 2421433358 (I 55)
# 281878236 (I 55)
# 281876950 (I 55)
# 281877007 (I 55)
# 281876727 (I 55)
# 2421433414 (I 55)
# 630274955 (I 55)
# 2421433417 (I 55)
# 630274958 (I 55)
# 2421433423 (I 55)
# 281876728 (I 55)
# 281876729 (I 55)
# 281876730 (I 55)
# 281876731 (I 55)
# 281877606 (NoName)
# 281877607 (NoName)
# 281877608 (NoName)
# 281877599 (NoName)
# 281877605 (I 240)
# 281876754 (I 240)
# 281876755 (I 240)
# 630275338 (I 240)
# 281876756 (I 240)
# 281876757 (I 240)
# 281876758 (I 240)
# 282129945 (I 240)
# 1780812179 (I 240)
# 281879383 (I 240)
# 1780812209 (I 240)
# 1780812178 (I 240)
# 1780812159 (I 240)
# 1780812236 (I 240)
# 1780812252 (I 240)
# 1933025724 (I 240)
# 281881118 (I 240)
# 281879385 (I 240)
# 281880782 (I 240)
# 282138928 (I 240)
# 282132237 (I 240)
# 282132179 (I 240)
# 2727461584 (I 240)
# 282132173 (I 240)
# 282132223 (I 240)
# 282132315 (I 240)
# 282132317 (I 240)
# 281881120 (I 240)
# 281880784 (I 240)
# 282132344 (I 240)
# 281879389 (I 240)
# 281881156 (I 240)
# 281879391 (I 240)
# 281879392 (I 240)
# 281879393 (I 240)
# 473491416 (I 240)
# 282139395 (I 240)
# 282139391 (I 240)
# 282139707 (I 240)
# 880296794 (I 240)
# 880296798 (I 240)
# 880296799 (I 240)
# 880296803 (I 240)
# 880296805 (I 240)
# 880296807 (I 240)
# 880296816 (I 240)
# 880296819 (I 240)
# 880296821 (I 240)
# 880296823 (I 240)
# 880296825 (I 240)
# 880296827 (I 240)
# 880296829 (I 240)
# 880296878 (I 240)
# 880296880 (I 240)
# 880296882 (I 240)
# 880296884 (I 240)
# 880296886 (I 240)
# 880296890 (I 240)
# 880296892 (I 240)
# 880296895 (I 240)
# 880296899 (I 240)
# 880296901 (I 240)
# 281879401 (I 240)
# 282140496 (I 240)
# 638887617 (I 240)
# 281881157 (I 240)
# 281880790 (I 240)
# 282140846 (I 240)
# 281881158 (I 240)
# 281879405 (I 240)
# 282140888 (I 240)
# 281880792 (I 240)
# 281879407 (I 240)
# 281881126 (I 240)
# 281880794 (I 240)
# 281881127 (I 240)
# 281879411 (I 240)
# 282141135 (I 240)
# 281880796 (I 240)
# 282141192 (I 240)
# 281879413 (I 240)
# 281879414 (I 240)
# 281879415 (I 240)
# 281881159 (I 240)
# 281879417 (I 240)
# 281879344 (I 240)
# 203619553 (I 240)
# 203617705 (I 240)
# 203773544 (I 240)
# 282141959 (I 240)
# 203617715 (I 240)
# 282142152 (I 240)
# 203773545 (I 240)
# 282142484 (I 240)
# 282142485 (I 240)
# 282142497 (I 240)
# 282142488 (I 240)
# 457244140 (I 240)
# 457244141 (I 240)
# 457244143 (I 240)
# 457244145 (I 240)
# 457244147 (I 240)
# 457244149 (I 240)
# 2081882529 (I 240)
# 457244151 (I 240)
# 457244152 (I 240)
# 457244154 (I 240)
# 638891002 (I 240)
# 457244158 (I 240)
# 457244161 (I 240)
# 457244162 (I 240)
# 638891001 (I 240)
# 457244163 (I 240)
# 638890995 (I 240)
# 457244165 (I 240)
# 457244170 (I 240)
# 457244171 (I 240)
# 457244174 (I 240)
# 638890966 (I 240)
# 2081882536 (I 240)
# 457244175 (I 240)
# 2081882538 (I 240)
# 2081882542 (I 240)
# 2081882544 (I 240)
# 457244178 (I 240)
# 457244180 (I 240)
# 638894222 (I 240)
# 638894225 (NoName)
# 457244580 (NoName)
# 1561110614 (NoName)
# 203616119 (NoName)
# 1561110615 (NoName)
# 203617005 (NoName)
# 638894138 (NoName)
# 1561110621 (NoName)
# 1561110622 (NoName)
# 203617009 (NoName)
# 203673450 (Walnut Grove Road)
# 2022431181 (Walnut Grove Road)
# 1561110624 (Walnut Grove Road)
# 203938615 (Walnut Grove Road)
# 1351005416 (Walnut Grove Road)
# 1351005417 (Walnut Grove Road)
# 1351005419 (Walnut Grove Road)
# 1351005423 (Walnut Grove Road)
# 1351005429 (Walnut Grove Road)
# 1351005435 (Walnut Grove Road)
# 1351005440 (Walnut Grove Road)
# 1351005444 (Walnut Grove Road)
# 1351005454 (Walnut Grove Road)
# 1351005457 (Walnut Grove Road)
# 1351005466 (Walnut Grove Road)
# 1351005473 (Walnut Grove Road)
# 1351005477 (Walnut Grove Road)
# 1351005481 (Walnut Grove Road)
# 1351005483 (Walnut Grove Road)
# 1351005485 (Walnut Grove Road)
# 1351005488 (Walnut Grove Road)
# 1351005491 (Walnut Grove Road)
# 1351005492 (Walnut Grove Road)
# 1351005493 (Walnut Grove Road)
# 1351005494 (Walnut Grove Road)
# 1352161025 (Walnut Grove Road)
# 1352161022 (Walnut Grove Road)
# 1352161015 (Walnut Grove Road)
# 1352161014 (Walnut Grove Road)
# 1352161023 (Farm Road)
# 203616293 (Farm Road)
# 1352161029 (Farm Road)
#
# Head north on Elvis Presley Boulevard
#      Drive for 1.22 miles (97.69 seconds)
# Turn right onto NoName
#      Drive for 0.26 miles (21.03 seconds)
# Turn right onto I 55
#      Drive for 0.39 miles (25.85 seconds)
# Turn right onto NoName
#      Drive for 0.16 miles (12.46 seconds)
# Turn right onto I 240
#      Drive for 11.72 miles (766.98 seconds)
# Turn right onto NoName
#      Drive for 0.30 miles (24.14 seconds)
# Turn right onto Walnut Grove Road
#      Drive for 1.49 miles (123.58 seconds)
# Turn left onto Farm Road
#      Drive for 0.17 miles (15.19 seconds)
# You have arrive!
